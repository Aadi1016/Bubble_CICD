# %%
import numpy as np
import pandas as pd
import os
import requests
import json
import csv

# %% [markdown]
# # Commit branch
# # Getting the Token for ORG - Shahjada_commit (Github Branch - Thoughtspot_commit)

# %%
# Authentication url for Commit API Call
auth_url = 'https://ps-internal.thoughtspot.cloud/api/rest/2.0/auth/token/full'

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}

payload = {
    "username": "md.shahjada@thoughtspot.com",
    "auto_create": False,
    "password": "Barauni851112@",
    "secret_key": "7a67cc93-8318-4ecd-aa41-5f455c359ece"
}

try:
    response = requests.post(auth_url, headers=headers, data=json.dumps(payload))
    response.raise_for_status()  # Raises error if status >= 400
    print(f"✅ Successfully Logged_in")
except requests.exceptions.RequestException as e:
    print(f"❌ Login Failed: {e}")


# Store the Bearer Token for next API calls 
json_text=response.json()
json_text['token']
Bearer_token = json_text['token']
# Out:
# ✅ Successfully Logged_in

# %% [markdown]
# # Commit in Version Control

# %%
# Metadata Search URL with TAG_IDENTIFIER
metadata_search_url = 'https://ps-internal.thoughtspot.cloud/api/rest/2.0/metadata/search'
# Version Control API url for COMMIT 
commit_url = 'https://ps-internal.thoughtspot.cloud/api/rest/2.0/vcs/git/branches/commit'

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {Bearer_token}'
}

payload = {
        "record_offset": 0,
        "record_size": 10000,
    "metadata": [
        {"type": "LIVEBOARD"},
        {"type": "ANSWER"},
        {"type": "LOGICAL_TABLE"},
        {"type": "CONNECTION"},
        {"type": "LOGICAL_RELATIONSHIP"}
    ],
        "tag_identifiers": ["CICD_TEST"],
        
}

try:
    response = requests.post(metadata_search_url, headers=headers, data=json.dumps(payload))
    response.raise_for_status()  # Raises error if status >= 400
    print(f"✅ Success for Metadata_Search API call")
except requests.exceptions.RequestException as e:
    print(f"❌ Failure for Metadata_Search API call: {e}")

# Store the Response in a variable
json_text=response.json()

# Create an empty list to store metadata_information
metadata_id = []
metadata_name = []
metadata_type = []

for i in json_text:
    metadata_id.append(i['metadata_id'])
    metadata_name.append(i['metadata_name'])
    metadata_type.append(i['metadata_type'])

# Create a dataframe and a CSV file to store the metadata information
df = pd.DataFrame()
df['metadata_id'] = metadata_id
df['metadata_name'] = metadata_name
df['metadata_type'] = metadata_type

df.to_csv('metadata_information.csv')

# Read GUIDs from CSV
metadata_df = pd.read_csv('metadata_information.csv')
metadata_df.drop(columns=['Unnamed: 0'] , inplace=True)

for i in range(len(metadata_df)) :
    guid = df['metadata_id'][i]
    
    payload = {
        "metadata": [
            {
                "identifier": guid
            }
        ],
        "delete_aware": True,
        "branch_name": "Thoughtspot_commit",
        "comment": "Testing CICD"
    }
    
    try:
        response = requests.post(commit_url, headers=headers, data=json.dumps(payload))
        response.raise_for_status()  # Raises error if status >= 400
        print(f"✅ Success for GUID {guid} , 'metadata_type': {df['metadata_type'][i]} , 'metadata_name': {df['metadata_name'][i]}" )
    except requests.exceptions.RequestException as e:
        print(e)
        print(f"❌ Failure for GUID {guid}, 'metadata_type': {df['metadata_type'][i]}, 'metadata_name': {df['metadata_name'][i]} — Error: {e}")
# Out:
# ✅ Success for Metadata_Search API call
# ✅ Success for GUID 5bb8eec3-891c-466b-999b-9edb5174234f , 'metadata_type': LIVEBOARD , 'metadata_name': Testing Liveboard-CI/CD
# ✅ Success for GUID 8d7b29f6-c682-4202-8556-1bdfce213b5a , 'metadata_type': ANSWER , 'metadata_name': Total quantity purchased, Total sales by county

# %% [markdown]
# # Deploy Branch
# # Getting the Token for ORG - Shahjada_commit (Github Branch - Thoughtspot_commit)

# %%
# Authentication url for Deploy API call 
deploy_auth_url = 'https://ps-internal.thoughtspot.cloud/api/rest/2.0/auth/token/full'

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json'
}

payload = {
    "username": "md.shahjada@thoughtspot.com",
    "auto_create": False,
    "password": "Barauni851112@",
    "secret_key": "285719de-f91c-49eb-bbf4-305483c8f324"
}

try:
    response = requests.post(deploy_auth_url, headers=headers, data=json.dumps(payload))
    response.raise_for_status()  # Raises error if status >= 400
    print(f"✅ Successfully Logged_in")
except requests.exceptions.RequestException as e:
    print(f"❌ Login Failed: {e}")

# Store the Bearer Token fro next API calls 
json_text=response.json()
json_text['token']
Bearer_token = json_text['token']
# Out:
# 200
# {'token': 'bWQuc2hhaGphZGFAdGhvdWdodHNwb3QuY29tOkpITm9hWEp2TVNSVFNFRXRNalUySkRVd01EQXdNQ1I2V21zeVlqUllNSEU0YkZWbFdYVkVlWEphTmtwUlBUMGtVWHBhUmxsRGJsZFdkbEo0VVhWaWRWbDFPUzlHUkRaSlkyMVNUekJIYlRBNVRtZHhlR2gxSzAxSWR6MA==', 'creation_time_in_millis': 1754392764772, 'expiration_time_in_millis': 1754393064606, 'scope': {'access_type': 'FULL', 'org_id': 2037951056, 'metadata_id': None}, 'valid_for_user_id': '00000848-d2e1-bf64-135d-7e57daf2dbad', 'valid_for_username': 'md.shahjada@thoughtspot.com'}

# %% [markdown]
# # Deploy to Thoughtspot

# %%
# This url deploy all the TML files from Github(Deploy branch) to your environment
deploy_url = 'https://ps-internal.thoughtspot.cloud/api/rest/2.0/vcs/git/commits/deploy'

headers = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': f'Bearer {Bearer_token}'
}

payload = {
    "branch_name": "Thoughtspot_deploy",
    "deploy_type": "DELTA",
    "deploy_policy": "ALL_OR_NONE"
}

try:
    response = requests.post(deploy_url, headers=headers, data=json.dumps(payload))
    response.raise_for_status()  # Raises error if status >= 400
    print(f"✅ Successfully Deployed")
except requests.exceptions.RequestException as e:
    print(f"❌ Deploy Failed: {e}")
# Out:
# 200
# [{"file_name":"25439bb2-9c64-412d-a81d-fcba1e65e7b4.tml","metadata_name":"State vs Sales-CI/CD","metadata_type":"ANSWER","status_code":"OK","status_message":"IMPORTED"}]

# %% [markdown]
# # Metadata Search with Tag Identifiers

# %%
# Out:
# 200
# [{"metadata_id":"5bb8eec3-891c-466b-999b-9edb5174234f","metadata_name":"Testing Liveboard-CI/CD","metadata_type":"LIVEBOARD","metadata_obj_id":null,"dependent_objects":null,"incomplete_objects":null,"metadata_detail":null,"metadata_header":{"hasTabs":false,"modelVersion":"V1","hasMandatoryFilter":false,"isMandatoryFilterValueSelected":true,"totalContainerCount":1,"id":"5bb8eec3-891c-466b-999b-9edb5174234f","indexVersion":228790,"generationNum":228790,"name":"Testing Liveboard-CI/CD","description":"","author":"00000848-d2e1-bf64-135d-7e57daf2dbad","authorName":"md.shahjada@thoughtspot.com","hasLenientDiscoverability":true,"descriptionAutoGenerated":false,"authorDisplayName":"md.shahjada@thoughtspot.com","created":1754307996315,"modified":1754310270957,"modifiedBy":"00000848-d2e1-bf64-135d-7e57daf2dbad","owner":"5bb8eec3-891c-466b-999b-9edb5174234f","isDeleted":false,"isHidden":false,"isAutoCreated":false,"isAutoDelete":false,"orgIds":[1250415082],"ownerOrgId":1250415082,"resolvedObjects":{},"tags":[{"id":"435589d9-482c-416e-ad19-a752b3f4015e","indexVersion":229674,"generationNum":229674,"name":"CICD_TEST","description":"undefined","author":"00000848-d2e1-bf64-135d-7e57daf2dbad","created":1754395867741,"modified":1754395867741,"modifiedBy":"00000848-d2e1-bf64-135d-7e57daf2dbad","owner":"435589d9-482c-416e-ad19-a752b3f4015e","isDeleted":false,"isHidden":false,"orgIds":[1250415082],"ownerOrgId":1250415082,"tags":[],"configs":[],"isConnectionConfigurationDisabled":false,"aiAnswerGenerationDisabled":true,"isExternal":false,"isDeprecated":false,"isSharedViaConnection":false,"syncWithSource":false,"isVerified":false,"isVersioningEnabled":false,"contentUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","headerUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","isPublished":false,"csrProtected":false}],"configs":[],"isConnectionConfigurationDisabled":false,"aiAnswerGenerationDisabled":true,"isExternal":false,"isDeprecated":false,"isSharedViaConnection":false,"syncWithSource":false,"isVerified":false,"isVersioningEnabled":false,"datasetId":"","subType":"","reportId":"","viewId":"","contentUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","headerUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","isPublished":false,"csrProtected":false},"visualization_headers":null,"stats":null},{"metadata_id":"8d7b29f6-c682-4202-8556-1bdfce213b5a","metadata_name":"Total quantity purchased, Total sales by county","metadata_type":"ANSWER","metadata_obj_id":null,"dependent_objects":null,"incomplete_objects":null,"metadata_detail":null,"metadata_header":{"isTimeSeriesKPI":false,"id":"8d7b29f6-c682-4202-8556-1bdfce213b5a","indexVersion":229672,"generationNum":229672,"name":"Total quantity purchased, Total sales by county","description":"","author":"00000848-d2e1-bf64-135d-7e57daf2dbad","authorName":"md.shahjada@thoughtspot.com","hasLenientDiscoverability":true,"descriptionAutoGenerated":false,"authorDisplayName":"md.shahjada@thoughtspot.com","created":1754395842166,"modified":1754395843025,"modifiedBy":"00000848-d2e1-bf64-135d-7e57daf2dbad","owner":"8d7b29f6-c682-4202-8556-1bdfce213b5a","isDeleted":false,"isHidden":false,"isAutoCreated":false,"isAutoDelete":false,"orgIds":[1250415082],"ownerOrgId":1250415082,"resolvedObjects":{},"tags":[{"id":"435589d9-482c-416e-ad19-a752b3f4015e","indexVersion":229674,"generationNum":229674,"name":"CICD_TEST","description":"undefined","author":"00000848-d2e1-bf64-135d-7e57daf2dbad","created":1754395867741,"modified":1754395867741,"modifiedBy":"00000848-d2e1-bf64-135d-7e57daf2dbad","owner":"435589d9-482c-416e-ad19-a752b3f4015e","isDeleted":false,"isHidden":false,"orgIds":[1250415082],"ownerOrgId":1250415082,"tags":[],"configs":[],"isConnectionConfigurationDisabled":false,"aiAnswerGenerationDisabled":true,"isExternal":false,"isDeprecated":false,"isSharedViaConnection":false,"syncWithSource":false,"isVerified":false,"isVersioningEnabled":false,"contentUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","headerUpgradeId":"MAPBOX_TOKEN_ROTATION_HANDLER","isPublished":f ...

# %%
# Out:
# 200
# {"committer":{"email":null,"username":"shahjada-286"},"author":{"email":"md.shahjada@thoughtspot.com","username":"md.shahjada@thoughtspot.com"},"comment":"5th Aug_Testing CICD","commit_time":"07/08/2025 11:15:43","commit_id":"4f97ea8081a468b9e56ee2bd8c2771a66cdab969","branch":"Thoughtspot_commit","committed_files":[{"file_name":"liveboard/Testing Liveboard-CI*CD.5bb8eec3-891c-466b-999b-9edb5174234f.liveboard.tml","status_code":"WARNING","status_message":"File not committed. There is no change compared to previous commit."},{"file_name":"liveboard/Sales Model - Testing.2afb3a14-f57e-4f4c-a4de-1c50d881a8b1.liveboard.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/Total Totalproductcost by Firstname.6ed7bf58-1ccc-4067-b2f3-bf70a080e28c.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/testing - 001.aada8994-b198-4d00-a361-21264d53d413.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/test-001.4757eb39-cb62-4596-9589-48b29439d0c8.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"worksheet/Sales Data Model.0f21baf9-c213-4d2f-ba77-b46ed5e9f18a.worksheet.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"table/FACTRESELLERSALES.85996e7d-96d8-42e8-a0b0-4465a9c6a95f.table.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"table/DIMEMPLOYEE.5262993d-d0d3-49db-81c3-43b0b6ec7fb7.table.tml","status_code":"OK","status_message":"DELETED"}]}
# 200
# {"committer":{"email":null,"username":"shahjada-286"},"author":{"email":"md.shahjada@thoughtspot.com","username":"md.shahjada@thoughtspot.com"},"comment":"5th Aug_Testing CICD","commit_time":"07/08/2025 11:15:46","commit_id":"e4a044af87abefcd4b936d68c20591b18fc23a11","branch":"Thoughtspot_commit","committed_files":[{"file_name":"answer/Total quantity purchased, Total sales by county.8d7b29f6-c682-4202-8556-1bdfce213b5a.answer.tml","status_code":"WARNING","status_message":"File not committed. There is no change compared to previous commit."},{"file_name":"liveboard/Sales Model - Testing.2afb3a14-f57e-4f4c-a4de-1c50d881a8b1.liveboard.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/Total Totalproductcost by Firstname.6ed7bf58-1ccc-4067-b2f3-bf70a080e28c.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/testing - 001.aada8994-b198-4d00-a361-21264d53d413.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"answer/test-001.4757eb39-cb62-4596-9589-48b29439d0c8.answer.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"worksheet/Sales Data Model.0f21baf9-c213-4d2f-ba77-b46ed5e9f18a.worksheet.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"table/FACTRESELLERSALES.85996e7d-96d8-42e8-a0b0-4465a9c6a95f.table.tml","status_code":"OK","status_message":"DELETED"},{"file_name":"table/DIMEMPLOYEE.5262993d-d0d3-49db-81c3-43b0b6ec7fb7.table.tml","status_code":"OK","status_message":"DELETED"}]}
